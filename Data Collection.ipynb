# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from IPython.display import display
# Using Client Credentials for authorization
client_credentials_manager = SpotifyClientCredentials(client_id="f2d11bfce2cf4bae8e096454ca4299ed",client_secret="0192b251aff04567a49d33d83287a254")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# get access token for spotify
token = client_credentials_manager.get_access_token()

# %%
playlist_0 = sp.user_playlist(user='21fanbzduelpkiu2q5zutudja',playlist_id="3lMjfwXLl16mLwsIGesy01")
playlist_1 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX4dyzvuaRJ0n")
playlist_2 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DXaXB8fQg7xif")
playlist_3 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX8tZsk68tuDw")
playlist_4 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DXcXBWjiVEM8R")
playlist_5 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX6VdMW310YC7")
playlist_6 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DXbraCN8mShma")
playlist_7 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX5wLEUgIR5Wy")
playlist_8 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2nTSE0")
playlist_9 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2NCvn4")
playlist_10 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0HRlzc")
playlist_11 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX46HBMApdlID")
playlist_12 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWVM4VqFGeMe4")
playlist_13 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO14OuVJ")
playlist_14 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX0hvSv9Rf41p")
playlist_15 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO07rbKo")
playlist_16 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0XdkGY")
playlist_17 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0qxgli")
playlist_18 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0dAjx6")
playlist_19 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO4cJYWI")
playlist_20 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO18wCGk")
playlist_21 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWWj5zlML0Fin")
playlist_22 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX9GbeR6sPmQb")
playlist_23 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO44XFa8")
playlist_24 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO4s4B1e")
playlist_25 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX94qaYRnkufr")
playlist_26 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DXbDs5HMNanrc")
playlist_27 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO1RBsv6")
playlist_28 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX9wiAG8jAIkT")
playlist_29 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWW3gTjSx5Dc7")
playlist_30 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX60EDqDORwwI")
playlist_31 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWYacvJEtDkU8")
playlist_32 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWZUWZIwpqsT3")
playlist_33 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX4npDJDFDYLg")
playlist_34 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3LIN0c")
playlist_35 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX0MiLwiDL8lJ")
playlist_36 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DXdFvkFPLsPi2")
playlist_37 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWWEIreSTav5P")
playlist_38 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX87JE1B72J6C")
playlist_39 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX7ro1070uuGs")
playlist_40 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX2rheAFbQM31")
playlist_41 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX3jrI7rYHIOI")
playlist_42 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO34U6QM")
playlist_43 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO1bnTX2")
playlist_44 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO4nb11C")
playlist_45 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWWVnzqQyu8XB")
playlist_46 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DXdIpacQDPDV5")
playlist_47 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2Hmegh")
playlist_48 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX4WYpdgoIcn6")
playlist_49 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3j3iRG")
playlist_50 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3Oe9Dq")
playlist_51 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO1JmxGK")
playlist_52 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2VqtkQ")
playlist_53 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX7H1BP5vXFoO")
playlist_54 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3GvGxi")
playlist_55 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3BPiTe")
playlist_56 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2sv2nJ")
playlist_57 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2lCxvq")
playlist_58 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2C8zDy")
playlist_59 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2XgRGg")
playlist_60 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2VjB72")
playlist_61 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2EPLna")
playlist_62 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO4tCQ8w")
playlist_63 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO4mcwgw")
playlist_64 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX7IOI7TbS1hG")
playlist_65 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3dMTOo")
playlist_66 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0ZBh0k")
playlist_67 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX1QOnQNx3HPL")
playlist_68 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0XAYVq")
playlist_69 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3NQvqE")
playlist_70 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0wZmve")
playlist_71 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3EYgz6")
playlist_72 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO1rXMLC")
playlist_73 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3j5vfW")
playlist_74 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWZmSR8ugtQ84")
playlist_75 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3vBedW")
playlist_76 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO4qJ09q")
playlist_77 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2CYOVG")
playlist_78 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO1U0v4Z")
playlist_79 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX6waq9bOfjwN")
playlist_80 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX7Ubb192UfSb")
playlist_81 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX1xlmTNXq2Qg")
playlist_82 = sp.user_playlist(user='spotify',playlist_id="0kGTTPDeNoqW57QnC5UBFn")
playlist_83 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3Fy0Vi")
playlist_84 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2GL6Ba")
playlist_85 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWTMYo3OZGoxV")
playlist_86 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DXdgz8ZB7c2CP")
playlist_87 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO3yRCdG")
playlist_88 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO2f027c")
playlist_89 = sp.user_playlist(user='spotify',playlist_id="3gfl5TX5T5cWBugZ71COzY")
playlist_90 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0er6Wu")
playlist_91 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO4jnUex")
playlist_92 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0vLbXi")
playlist_93 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0kKpwc")
playlist_94 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX7nGw3hwYw03")
playlist_95 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0YpiQE")
playlist_96 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX0MiLwiDL8lJ")
playlist_97 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DZ06evO0dAjx6")
playlist_98 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWTDkgFD3ivE6")
playlist_99 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DWTDnCxoyoneS")
playlist_100 = sp.user_playlist(user='spotify',playlist_id="37i9dQZF1DX7RSP4HQfoPY")
